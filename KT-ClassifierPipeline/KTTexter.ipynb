# %%
import json

# %%
with open('files/Kairntech.json') as fp:
    k = json.load(fp)

# %%
x = 40
pre = 1
new = []
for key in k:  
    val = k.pop(0) 
    if x > 0:
        new.append(val)
        x -= 1
    else:
        with open('ktImports/kt'+str(pre)+'.json','w+') as fp:
            json.dump(new,fp)
        x = 40
        pre += 1
        new = []
        new.append(val)
        x -= 1
with open('ktImports/kt'+str(pre)+'.json','w+') as fp:
    json.dump(new,fp)

# %%
len(k)
# Out:
# 274

# %%
for x in k:
    print(x['categories'][0])
# Out:
# {'label': 'b2find#5.2.2.03', 'score': 1.0}
# {'label': 'b2find#3.3.2.04', 'score': 0.4688149688149689}
# {'label': 'b2find#3.1.1.01', 'score': 1.0}
# {'label': 'b2find#1.1.2', 'score': 1.0}
# {'label': 'b2find#3.2.2.12', 'score': 0.656706045865184}
# {'label': 'b2find#2.2.1', 'score': 0.9567711807871916}
# {'label': 'b2find#1.8.3', 'score': 0.37245378151260505}
# {'label': 'b2find#3.1.1.01', 'score': 0.4562154001006542}
# {'label': 'b2find#1.6.2', 'score': 1.0}
# {'label': 'b2find#2.1.3', 'score': 0.7902097902097903}
# {'label': 'b2find#3.3.1.09', 'score': 0.5297113752122241}
# {'label': 'b2find#4.3.3', 'score': 1.0}
# {'label': 'b2find#1.2.1', 'score': 0.3035714285714286}
# {'label': 'b2find#1.5.2', 'score': 0.8882309400444115}
# {'label': 'b2find#3.2.2.17', 'score': 1.0}
# {'label': 'b2find#3.2.1.03', 'score': 0.8033240997229915}
# {'label': 'b2find#3.1.2.02', 'score': 0.8977403806541979}
# {'label': 'b2find#2.1.3', 'score': 0.6956521739130437}
# ...

# %%
import json
for x in range(1,7):
    with open('files/kt'+str(x)+'.json') as fp:
        file = json.load(fp)

    print(f'kt{x}: {len(file)=}')
# Out:
# kt1: len(file)=40
# kt2: len(file)=40
# kt3: len(file)=40
# kt4: len(file)=40
# kt5: len(file)=40
# kt6: len(file)=40
